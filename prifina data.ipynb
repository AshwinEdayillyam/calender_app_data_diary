# %%
import pandas as pd

# %%
df=pd.read_csv('Prifina Data.csv')

# %%
df
# Out:
#        Age   Spending Region Downloaded
# 0     29.0  3113018.0  Urban        Yes
# 1     30.0  3686821.0  Urban        Yes
# 2     25.0  3910136.0    NaN         No
# 3      NaN  5471600.0  Rural        Yes
# 4     17.0  4533064.0  Rural         No
# ...    ...        ...    ...        ...
# 2170  39.0  6521703.0  Urban        Yes
# 2171  43.0        NaN  Urban        Yes
# 2172  26.0  3681520.0  Rural         No
# 2173  34.0  6488616.0  Urban        Yes
# 2174  18.0  1575425.0  Rural        Yes
#
# [2175 rows x 4 columns]

# %%
df['Region'].value_counts()
# Out:
# Urban    1367
# Rural     786
# Name: Region, dtype: int64

# %%
df['Downloaded'].value_counts()
# Out:
# Yes    1392
# No      763
# Name: Downloaded, dtype: int64

# %%
df['Region'] = df['Region'].replace({"Urban": 1, "Rural":0})
df['Downloaded'] = df['Downloaded'].replace({"Yes": 1, "No":0})

df
# Out:
#        Age   Spending  Region  Downloaded
# 0     29.0  3113018.0     1.0         1.0
# 1     30.0  3686821.0     1.0         1.0
# 2     25.0  3910136.0     NaN         0.0
# 3      NaN  5471600.0     0.0         1.0
# 4     17.0  4533064.0     0.0         0.0
# ...    ...        ...     ...         ...
# 2170  39.0  6521703.0     1.0         1.0
# 2171  43.0        NaN     1.0         1.0
# 2172  26.0  3681520.0     0.0         0.0
# 2173  34.0  6488616.0     1.0         1.0
# 2174  18.0  1575425.0     0.0         1.0
#
# [2175 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2175 entries, 0 to 2174
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         2162 non-null   float64
#  1   Spending    2155 non-null   float64
#  2   Region      2153 non-null   float64
#  3   Downloaded  2155 non-null   float64
# dtypes: float64(4)
# memory usage: 68.1 KB

# %% [markdown]
# # Handling missing Data

# %%
df = df.fillna(df.mean().round())
df
# Out:
#        Age   Spending  Region  Downloaded
# 0     29.0  3113018.0     1.0         1.0
# 1     30.0  3686821.0     1.0         1.0
# 2     25.0  3910136.0     1.0         0.0
# 3     30.0  5471600.0     0.0         1.0
# 4     17.0  4533064.0     0.0         0.0
# ...    ...        ...     ...         ...
# 2170  39.0  6521703.0     1.0         1.0
# 2171  43.0  4776221.0     1.0         1.0
# 2172  26.0  3681520.0     0.0         0.0
# 2173  34.0  6488616.0     1.0         1.0
# 2174  18.0  1575425.0     0.0         1.0
#
# [2175 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2175 entries, 0 to 2174
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         2175 non-null   float64
#  1   Spending    2175 non-null   float64
#  2   Region      2175 non-null   float64
#  3   Downloaded  2175 non-null   float64
# dtypes: float64(4)
# memory usage: 68.1 KB

# %% [markdown]
# # Justify X and Y

# %%
x = df.iloc[:,0:-1]
y = df.iloc[:,-1:]

# %%
x
# Out:
#        Age   Spending  Region
# 0     29.0  3113018.0     1.0
# 1     30.0  3686821.0     1.0
# 2     25.0  3910136.0     1.0
# 3     30.0  5471600.0     0.0
# 4     17.0  4533064.0     0.0
# ...    ...        ...     ...
# 2170  39.0  6521703.0     1.0
# 2171  43.0  4776221.0     1.0
# 2172  26.0  3681520.0     0.0
# 2173  34.0  6488616.0     1.0
# 2174  18.0  1575425.0     0.0
#
# [2175 rows x 3 columns]

# %%
y
# Out:
#       Downloaded
# 0            1.0
# 1            1.0
# 2            0.0
# 3            1.0
# 4            0.0
# ...          ...
# 2170         1.0
# 2171         1.0
# 2172         0.0
# 2173         1.0
# 2174         1.0
#
# [2175 rows x 1 columns]
